# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief
#
# Write the YML for the following questions.

# %% [markdown]
# ## Instructions
#
# Paste the answer as YML in the answer code section below each question.

# %% [markdown]
# ### Question 1
#
# Question: Add 2 more tests each using `dbt_utils` and `dbt-expectations` to `fact_sales`.
#
# Specs for `dbt_utils`:
#
# ```yaml
# models:
#   - name: fact_sales
#     tests:
#       - dbt_utils.expression_is_true:
#           arguments:
#             expression: "sale_dollars IS NOT NULL"
#           severity: error
#
#       - dbt_utils.expression_is_true:
#           arguments:
#             expression: "bottles_sold IS NOT NULL"
#           severity: error
# ```
#
# Specs for `dbt-expectations`:
#
# ```yaml
# models:
#   - name: fact_sales
#     columns:
#       - name: invoice_and_item_number
#         tests:
#           - dbt_expectations.expect_column_values_to_be_of_type:
#               arguments:
#                 column_type: string
#
#       - name: date
#         tests:
#           - dbt_expectations.expect_column_values_to_be_of_type:
#               arguments:
#                 column_type: date
# ```
